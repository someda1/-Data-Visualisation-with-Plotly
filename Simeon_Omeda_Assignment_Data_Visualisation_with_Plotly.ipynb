# %% [markdown]
# Simeon Omeda Assignment: Data Visualisation with Plotly

# %% [markdown]
# *Prerequisites*

# %%
# Import pandas for data manipulation
import pandas as pd

# Import numpy for scientific computations
import numpy as np

# Import plotly library for data visualisation
# ---
# `plotly.express` contains plotly.py's core functionality
# ----
#
import plotly.express as px

# %% [markdown]
# *Prepare the data*

# %%
# import the data
mobile_df = pd.read_csv('https://bit.ly/MobileDataset')
mobile_df.head()
# Out:
#                        Series Name     Series Code        Country Name  \
# 0  Internet users (per 100 people)  IT.NET.USER.P2  Sub-Saharan Africa
# 1  Internet users (per 100 people)  IT.NET.USER.P2              Angola
# 2  Internet users (per 100 people)  IT.NET.USER.P2               Benin
# 3  Internet users (per 100 people)  IT.NET.USER.P2            Botswana
# 4  Internet users (per 100 people)  IT.NET.USER.P2        Burkina Faso
#
#   Country Code 1995 [YR1995] 1996 [YR1996] 1997 [YR1997] 1998 [YR1998]  \
# 0          SSF            ..   0.068722178   0.128779789   0.233989844
# 1          AGO            ..   0.000775929   0.005673746   0.018453724
# 2          BEN            ..     0.0016931   0.024648796   0.047877304
# 3          BWA   0.064521041    0.15745423    0.30774685   0.602400929
# 4          BFA            ..   0.000960519   0.018686353   0.045423484
#
#   1999 [YR1999] 2000 [YR2000]  ... 2007 [YR2007] 2008 [YR2008] 2009 [YR2009]  \
# ...

# %%
#check the data type
mobile_df.dtypes
# Out:
# Series Name      object
# Series Code      object
# Country Name     object
# Country Code     object
# 1995 [YR1995]    object
# 1996 [YR1996]    object
# 1997 [YR1997]    object
# 1998 [YR1998]    object
# 1999 [YR1999]    object
# 2000 [YR2000]    object
# 2001 [YR2001]    object
# 2002 [YR2002]    object
# 2003 [YR2003]    object
# 2004 [YR2004]    object
# 2005 [YR2005]    object
# 2006 [YR2006]    object
# 2007 [YR2007]    object
# 2008 [YR2008]    object
# 2009 [YR2009]    object
# 2010 [YR2010]    object
# 2011 [YR2011]    object
# 2012 [YR2012]    object
# 2013 [YR2013]    object
# 2014 [YR2014]    object
# 2015 [YR2015]    object
# 2016 [YR2016]    object
# dtype: object

# %%
#check the number of rows and columns
mobile_df.shape
# Out:
# (715, 26)

# %%
#take a loot at the first 5 records
mobile_df.head(5)
# Out:
#                        Series Name     Series Code        Country Name  \
# 0  Internet users (per 100 people)  IT.NET.USER.P2  Sub-Saharan Africa
# 1  Internet users (per 100 people)  IT.NET.USER.P2              Angola
# 2  Internet users (per 100 people)  IT.NET.USER.P2               Benin
# 3  Internet users (per 100 people)  IT.NET.USER.P2            Botswana
# 4  Internet users (per 100 people)  IT.NET.USER.P2        Burkina Faso
#
#   Country Code 1995 [YR1995] 1996 [YR1996] 1997 [YR1997] 1998 [YR1998]  \
# 0          SSF            ..   0.068722178   0.128779789   0.233989844
# 1          AGO            ..   0.000775929   0.005673746   0.018453724
# 2          BEN            ..     0.0016931   0.024648796   0.047877304
# 3          BWA   0.064521041    0.15745423    0.30774685   0.602400929
# 4          BFA            ..   0.000960519   0.018686353   0.045423484
#
#   1999 [YR1999] 2000 [YR2000]  ... 2007 [YR2007] 2008 [YR2008] 2009 [YR2009]  \
# ...

# %%
# removing trailing or leading spaces and characers
mobile_df.columns = mobile_df.columns.str.strip().str.replace(' ', '_')

mobile_df.head()
# Out:
#                        Series_Name     Series_Code        Country_Name  \
# 0  Internet users (per 100 people)  IT.NET.USER.P2  Sub-Saharan Africa
# 1  Internet users (per 100 people)  IT.NET.USER.P2              Angola
# 2  Internet users (per 100 people)  IT.NET.USER.P2               Benin
# 3  Internet users (per 100 people)  IT.NET.USER.P2            Botswana
# 4  Internet users (per 100 people)  IT.NET.USER.P2        Burkina Faso
#
#   Country_Code 1995_[YR1995] 1996_[YR1996] 1997_[YR1997] 1998_[YR1998]  \
# 0          SSF            ..   0.068722178   0.128779789   0.233989844
# 1          AGO            ..   0.000775929   0.005673746   0.018453724
# 2          BEN            ..     0.0016931   0.024648796   0.047877304
# 3          BWA   0.064521041    0.15745423    0.30774685   0.602400929
# 4          BFA            ..   0.000960519   0.018686353   0.045423484
#
#   1999_[YR1999] 2000_[YR2000]  ... 2007_[YR2007] 2008_[YR2008] 2009_[YR2009]  \
# ...

# %%
mobile_df.shape
# Out:
# (715, 26)

# %%
# check for missing values in each column 
mobile_df.isnull().sum()
# Out:
# Series_Name      0
# Series_Code      0
# Country_Name     0
# Country_Code     0
# 1995_[YR1995]    0
# 1996_[YR1996]    0
# 1997_[YR1997]    0
# 1998_[YR1998]    0
# 1999_[YR1999]    0
# 2000_[YR2000]    0
# 2001_[YR2001]    0
# 2002_[YR2002]    0
# 2003_[YR2003]    0
# 2004_[YR2004]    0
# 2005_[YR2005]    0
# 2006_[YR2006]    0
# 2007_[YR2007]    0
# 2008_[YR2008]    0
# 2009_[YR2009]    0
# 2010_[YR2010]    0
# 2011_[YR2011]    0
# 2012_[YR2012]    0
# 2013_[YR2013]    0
# 2014_[YR2014]    0
# 2015_[YR2015]    0
# 2016_[YR2016]    0
# dtype: int64

# %%
mobile_df.shape
# Out:
# (715, 26)

# %%
# Checking for duplicates;
#mobile_df = mobile_df[mobile_df.duplicated()]
#sum(mobile_df.duplicated())
# Out:
# 0

# %%
#checking for null values
mobile_df.isnull().any()
# Out:
# Series_Name      False
# Series_Code      False
# Country_Name     False
# Country_Code     False
# 1995_[YR1995]    False
# 1996_[YR1996]    False
# 1997_[YR1997]    False
# 1998_[YR1998]    False
# 1999_[YR1999]    False
# 2000_[YR2000]    False
# 2001_[YR2001]    False
# 2002_[YR2002]    False
# 2003_[YR2003]    False
# 2004_[YR2004]    False
# 2005_[YR2005]    False
# 2006_[YR2006]    False
# 2007_[YR2007]    False
# 2008_[YR2008]    False
# 2009_[YR2009]    False
# 2010_[YR2010]    False
# 2011_[YR2011]    False
# 2012_[YR2012]    False
# 2013_[YR2013]    False
# 2014_[YR2014]    False
# 2015_[YR2015]    False
# 2016_[YR2016]    False
# dtype: bool

# %%
mobile_df.shape
# Out:
# (715, 26)

# %%
# Dropping null values

mobile_df.dropna(inplace=True)
mobile_df.isna().sum()
# Out:
# Series_Name      0
# Series_Code      0
# Country_Name     0
# Country_Code     0
# 1995_[YR1995]    0
# 1996_[YR1996]    0
# 1997_[YR1997]    0
# 1998_[YR1998]    0
# 1999_[YR1999]    0
# 2000_[YR2000]    0
# 2001_[YR2001]    0
# 2002_[YR2002]    0
# 2003_[YR2003]    0
# 2004_[YR2004]    0
# 2005_[YR2005]    0
# 2006_[YR2006]    0
# 2007_[YR2007]    0
# 2008_[YR2008]    0
# 2009_[YR2009]    0
# 2010_[YR2010]    0
# 2011_[YR2011]    0
# 2012_[YR2012]    0
# 2013_[YR2013]    0
# 2014_[YR2014]    0
# 2015_[YR2015]    0
# 2016_[YR2016]    0
# dtype: int64

# %%
mobile_df3 = list(mobile_df.columns[1:])
mobile_df4 = mobile_df2.groupby('Series_Name', as_index=False).sum()
mobile_df4.head()
# Out:
#                                          Series_Name  \
# 0                      Fixed broadband subscriptions
# 1     Fixed broadband subscriptions (per 100 people)
# 2                      Fixed telephone subscriptions
# 3     Fixed telephone subscriptions (per 100 people)
# 4  High-technology exports (% of manufactured exp...
#
#                                          Series_Code  \
# 0  IT.NET.BBNDIT.NET.BBNDIT.NET.BBNDIT.NET.BBNDIT...
# 1  IT.NET.BBND.P2IT.NET.BBND.P2IT.NET.BBND.P2IT.N...
# 2  IT.MLT.MAINIT.MLT.MAINIT.MLT.MAINIT.MLT.MAINIT...
# 3  IT.MLT.MAIN.P2IT.MLT.MAIN.P2IT.MLT.MAIN.P2IT.M...
# 4  TX.VAL.TECH.MF.ZSTX.VAL.TECH.MF.ZSTX.VAL.TECH....
#
#                                         Country_Name  \
# 0  Sub-Saharan AfricaAngolaBeninBotswanaBurkina F...
# 1  Sub-Saharan AfricaAngolaBeninBotswanaBurkina F...
# 2  Sub-Saharan AfricaAngolaBeninBotswanaBurkina F...
# 3  Sub-Saharan AfricaAngolaBeninBotswanaBurkina F...
# ...

# %%
mobile_df4.transpose().reset_index()
mobile_df4
# Out:
#                                           Series_Name  \
# 0                       Fixed broadband subscriptions
# 1      Fixed broadband subscriptions (per 100 people)
# 2                       Fixed telephone subscriptions
# 3      Fixed telephone subscriptions (per 100 people)
# 4   High-technology exports (% of manufactured exp...
# 5               High-technology exports (current US$)
# 6        ICT goods exports (% of total goods exports)
# 7           ICT goods imports (% total goods imports)
# 8     ICT service exports (% of service exports, BoP)
# 9              ICT service exports (BoP, current US$)
# 10                    Internet users (per 100 people)
# 11                      Mobile cellular subscriptions
# 12     Mobile cellular subscriptions (per 100 people)
#
#                                           Series_Code  \
# 0   IT.NET.BBNDIT.NET.BBNDIT.NET.BBNDIT.NET.BBNDIT...
# 1   IT.NET.BBND.P2IT.NET.BBND.P2IT.NET.BBND.P2IT.N...
# ...

# %%
fig = px.line(
    mobile_df,
    x = "Series_Na",
    y = "",
   color = 0,
)
fig.update_layout(
    title = {
        'text': "Mobile Evolution Trends Over the Years",
        'x': 0.5,
        'font_size' : 15,
        'xanchor': "center",
        'yanchor': "auto"
    },
xaxis_title_text = "Years",
yaxis_title_text = "Users",
)

#Plot display

fig.show()
# Out:
# (13, 26)
